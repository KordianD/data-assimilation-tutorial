# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return (np.sin((2*np.pi*x)/23) + np.sin((2*np.pi*x)/28) + np.sin((2*np.pi*x)/33) )* np.log(x)

x = range(1, 1000)
y = [f(elem) for elem in x]

plt.figure(figsize=(20, 10))
plt.plot(x, y)
